# %% [markdown]
# ## Unir y preparar los ficheros bajados de IVIMA.
#
# Los datos del IVIMA hay que bajarlos manualmente desde: http://www.planalquila.org/

# %%
## Imports y directorios in/out

import pandas as pd
import os
import numpy as np

input_dir = '../../../data/raw/IVIMA/'
out_dir = '../../../data/clean/IVIMA/'
aux_dir = '../../../data/raw/OTROS/'


input_files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]

out_file = os.path.join(input_dir, 'ivima_cat.csv')
# !rm $out_file
# !touch $out_file

for f in input_files:
    if f <> out_file:
        # !cat $f >> $out_file

rawdata = pd.read_csv(out_file, sep='\t')

# Eliminar columnas no útiles
rawdata.drop(['Foto', 'Ref.', 'Fecha oferta', 'Unnamed: 9'], axis=1, inplace=True)

# Eliminar duplicados
rawdata = rawdata.drop_duplicates()

# Damos nombres "normales" a las columnas
rawdata.rename(columns={'Dirección':'Direccion', 'm²':'metros', 'Nºhab.':'habitaciones'}, inplace=True)

# Eliminar filas sin datos en predictores (Planta, m2, Precio)

rawdata = rawdata.dropna(subset=['Planta', 'metros','Precio'])

# Marcar garage 1=Si, 0=No
rawdata['Garaje']=rawdata.apply(lambda x: 1 if x['Garaje'] == 'si' else 0, axis = 1)

# al concatenar se han quedado los encabezados como datos, los eliminamos

rawdata = rawdata[rawdata['Precio'] != 'Precio']

# Convertir a tipo de dato correcto: metros y €

rawdata['Precio'] = rawdata['Precio'].str.replace(',', '.').str.replace('€', '').str.strip()

rawdata['Precio'] = rawdata['Precio'].map(float)

rawdata['metros'] = rawdata['metros'].str.replace(',', '.').str.strip()

rawdata['metros'] = rawdata['metros'].map(float)
# Out:
# rm: no se puede borrar '../../../data/raw/IVIMA/ivima_cat.csv': No existe el archivo o el directorio

# %%
# Analizamos los datos de € y metros que van a condicionar el modelo

# %%
rawdata['eur_metro'] = (rawdata['Precio']/rawdata['metros'])
rawdata['eur_metro_round'] = rawdata['eur_metro'].apply(lambda x: round(x, ndigits = 1))

# %%
rawdata.describe()
# Out:
#             metros       Garaje       Precio    eur_metro  eur_metro_round
# count  5656.000000  5656.000000  5656.000000  5656.000000      5656.000000
# mean     59.490818     0.190240   691.777801    12.563874        12.563543
# std      55.835065     0.392525   188.677759     3.908525         3.908971
# min       6.470000     0.000000   300.000000     0.120633         0.100000
# 25%      45.000000     0.000000   570.000000     9.992006        10.000000
# 50%      56.450000     0.000000   650.000000    11.791749        11.800000
# 75%      70.000000     0.000000   750.000000    14.285714        14.300000
# max    3979.000000     1.000000  2500.000000    85.007728        85.000000

# %%
# Analizamos los valores atípicos en base a € x metro cuadrado

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
# %matplotlib inline

# %%
sns.distplot(rawdata['metros'])
plt.show()

# %%
plt.scatter(rawdata['eur_metro'], rawdata['metros'])
plt.show()

# %%
# Hay 2 valores muy próximos a cero € x m2

# %%
liminf = np.exp(np.mean(np.log(rawdata['eur_metro']))-3*(np.std(np.log(rawdata['eur_metro']))))

# %%
rawdata[rawdata['eur_metro']<liminf]
# Out:
#                Direccion Planta  metros habitaciones  Garaje  Precio  \
# 3781    CALLE AMPARO, 12      4   335.0            2       0   685.0
# 4815  CALLE CARABIAS, 20      2  3979.0            2       0   480.0
#
#       eur_metro  eur_metro_round
# 3781   2.044776              2.0
# 4815   0.120633              0.1

# %%
# Eliminamos los 2 valores demasiado próximos a 0

# %%
rawdata.drop(rawdata[rawdata['eur_metro']<liminf].index, inplace=True)

# %%
sns.distplot(rawdata['metros'], kde=False)
plt.show()

# %%
sns.lmplot(x='metros', y='Precio', data = rawdata, hue = "Garaje")
plt.show()

# %%
rawdata.describe()
# Out:
#             metros       Garaje       Precio    eur_metro  eur_metro_round
# count  5654.000000  5654.000000  5654.000000  5654.000000      5654.000000
# mean     58.748862     0.190308   691.816456    12.567935        12.567616
# std      19.674518     0.392579   188.690085     3.903203         3.903617
# min       6.470000     0.000000   300.000000     5.633803         5.600000
# 25%      45.000000     0.000000   570.000000     9.995226        10.000000
# 50%      56.425000     0.000000   650.000000    11.794593        11.800000
# 75%      70.000000     0.000000   750.000000    14.285714        14.300000
# max     173.870000     1.000000  2500.000000    85.007728        85.000000

# %%
## Estudiamos los valores de euros

# %%
sns.distplot(rawdata['Precio'], kde=False)
plt.show()

# %%
rawdata[rawdata['Precio']>1800]
# Out:
#                         Direccion Planta     metros habitaciones  Garaje  \
# 1099     CALLE DOCTOR FLEMING, 11      2  165.60225            5       0
# 1177              CALLE POTOSI, 4      4  110.91000            3       1
# 3915               CALLE JESUS, 2      2  157.00000            3       0
# 4101  CUESTA DE SANTO DOMINGO, 22      3  173.00000            4       0
# 4681            CALLE LAGASCA, 95      3  103.00000            3       0
#
#       Precio  eur_metro  eur_metro_round
# 1099  2500.0  15.096413             15.1
# 1177  1850.0  16.680191             16.7
# 3915  2000.0  12.738854             12.7
# 4101  2000.0  11.560694             11.6
# 4681  1850.0  17.961165             18.0

# %%
## Los valores de precio no parecen presentar problemas

# %%
sns.distplot(rawdata['eur_metro'], kde=False)
plt.show()

# %%
# Traducir los valores de planta a los que existen en catastro para que el modelo se pueda
# aplicar a los datos reales
planta_ivima = pd.DataFrame((rawdata['Planta'].value_counts()).reset_index())

# %%
planta_ivima.rename(columns={'index':'planta', 'Planta':'elementos'}, inplace=True)

# %%
planta_ivima
# Out:
#    planta  elementos
# 0       1       1094
# 1       2       1067
# 2       3        990
# 3       4        695
# 4       5        330
# 5    BAJO        262
# 6       6        216
# 7      BJ        168
# 8       7        126
# 9       8         87
# 10     1º         78
# 11     2º         69
# 12     3º         61
# 13      9         52
# 14      B         42
# 15     4º         37
# 16     10         36
# 17    BJO         32
# 18     PB         32
# 19     11         26
# 20  ATICO         17
# 21     5º         15
# 22     6º         14
# 23     SS         13
# 24     12         12
# 25     7º          9
# 26     13          9
# 27     14          5
# 28     AT          4
# 29     ST          3
# ..    ...        ...
# 43     8º          1
# 44      S          1
# 45   ATIC          1
# 46     Bº          1
# 47     pb          1
# 48      0          1
# 49  LOCAL          1
# 50     SO          1
# 51   SOTA          1
# 52  IZQDA          1
# 53    IZQ          1
# 54    11º          1
# 55   PPAL          1
# 56     17          1
# 57  ENTPT          1
# 58   BJAO          1
# 59   ESTU          1
# 60  ENT-1          1
# 61  atico          1
# 62     SM          1
# 63     EP          1
# 64   BAJA          1
# 65     bj          1
# 66    8ºB          1
# 67      D          1
# 68    1-B          1
# 69   B-EN          1
# 70     9º          1
# 71    5 D          1
# 72   1º d          1
#
# [73 rows x 2 columns]

# %%
## Para cada planta de IVIMA hay que asociar el equivalente en catastro

# %%
## Añadimos una columna para buscar en catastro quitando los caracteres que no sean
# números ni letras 'º', asi tendremos los números

# %%
caracter_raro = planta_ivima[planta_ivima['planta'].str.contains('\W+')]['planta'].str.extract('(\W+)').unique()
# Out:
# /home/manu/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   if __name__ == '__main__':

# %%
caracter_raro
# Out:
# array(['\xc2\xba', '/', '-', ' ', '\xc2\xba '], dtype=object)

# %%
planta_ivima['planta_busqueda'] = planta_ivima['planta']

for raro in caracter_raro:
    planta_ivima['planta_busqueda'] = planta_ivima['planta_busqueda'].str.replace(raro, '')

# %%
##planta_ivima['planta_busqueda'] = planta_ivima['planta'].str.replace('º', '')

# %%
## La codificación de planta en catastro es de 2 caracteres

# %%
planta_ivima['planta_busqueda'] = planta_ivima['planta_busqueda'].apply(lambda x: '0' + x if len(x)==1 else x)

# %%
clean_dir = '../../data/clean/ficheros_preparados/'

# %%
cat_data =  pd.read_csv(os.path.join(clean_dir, 'BI_28_900_U_2016-01-23.csv.gz'), low_memory=False, dtype='str')

# %%
# Solo estamos interesados en los bienes inmuebles del tipo vivienda
planta_cat = pd.DataFrame(cat_data[cat_data['clave_grupo_BI']=='V']['planta'].value_counts().reset_index())

# %%
planta_cat.rename(columns={'index':'planta_cat', 'planta':'elementos'}, inplace=True)

# %%
# Poblamos en plantas ivima los cruces directos

# %%
planta_ivima = pd.merge(planta_ivima, planta_cat, how='left', left_on='planta_busqueda', right_on='planta_cat', suffixes=('ivi', 'cat'))

# %%
## Exportamos la tabla para revisión manual de las asociaciones que no cruzan directamente

# %%
planta_ivima.to_csv(os.path.join(aux_dir, 'plantas_ivima.csv'))

# %%
planta_ivima_revisada = pd.read_csv(os.path.join(out_dir, 'plantas_ivima.csv'), sep=';', index_col=0)

# %%
planta_ivima_revisada = planta_ivima_revisada.drop(['planta', 'elementosivi', 'planta_busqueda', 'elementoscat'], axis=1)

# %%
planta_ivima = pd.merge(planta_ivima, planta_ivima_revisada, left_index=True, right_index=True)

# %%
planta_ivima = planta_ivima.drop(['planta_busqueda', 'planta_cat_x', 'elementoscat', 'elementosivi'], axis=1)

# %%
planta_ivima.head()
# Out:
#   planta planta_cat_y
# 0      1           01
# 1      2           02
# 2      3           03
# 3      4           04
# 4      5           05

# %%
planta_ivima.rename(columns={'planta':'Planta', 'planta_cat_y':'planta_cat'}, inplace=True)

# %%
# poblamos los literales de planta de catastro en la tabla de datos

# %%
rawdata.head()
# Out:
#                           Direccion Planta  metros habitaciones  Garaje  \
# 0         AVENIDA DE MORATALAZ, 103      2   85.00            3       0
# 1          AVENIDA DE MORATALAZ, 29      4   41.67            2       0
# 2          AVENIDA DE MORATALAZ, 73      3   55.00            3       0
# 3          AVENIDA DE MORATALAZ, 85   BAJO   54.60            3       0
# 5  AVENIDA DOCTOR GARCIA TAPIA, 102     BJ   43.50            2       0
#
#    Precio  eur_metro  eur_metro_round
# 0   850.0  10.000000             10.0
# 1   600.0  14.398848             14.4
# 2   620.0  11.272727             11.3
# 3   650.0  11.904762             11.9
# 5   600.0  13.793103             13.8

# %%
rawdata = pd.merge(rawdata, planta_ivima, how='left', left_on='Planta', right_on='Planta')

# %%
rawdata.head()
# Out:
#                           Direccion Planta  metros habitaciones  Garaje  \
# 0         AVENIDA DE MORATALAZ, 103      2   85.00            3       0
# 1          AVENIDA DE MORATALAZ, 29      4   41.67            2       0
# 2          AVENIDA DE MORATALAZ, 73      3   55.00            3       0
# 3          AVENIDA DE MORATALAZ, 85   BAJO   54.60            3       0
# 4  AVENIDA DOCTOR GARCIA TAPIA, 102     BJ   43.50            2       0
#
#    Precio  eur_metro  eur_metro_round planta_cat
# 0   850.0  10.000000             10.0         02
# 1   600.0  14.398848             14.4         04
# 2   620.0  11.272727             11.3         03
# 3   650.0  11.904762             11.9         BJ
# 4   600.0  13.793103             13.8         BJ

# %%
# separamos la direccion en calle y número. Lo necesitaremos en R para buscar el año de la finca en el catastro

# %%
direcciones = rawdata['Direccion'].str.split(',', expand = True)

# %%
direcciones.drop(2, axis=1, inplace = True)

# %%
direcciones.rename(columns={0:'Calle', 1:'numero'}, inplace=True)

# %%
rawdata = pd.concat([rawdata, direcciones], axis = 1)

# %%
rawdata.head()
# Out:
#                           Direccion Planta  metros habitaciones  Garaje  \
# 0         AVENIDA DE MORATALAZ, 103      2   85.00            3       0
# 1          AVENIDA DE MORATALAZ, 29      4   41.67            2       0
# 2          AVENIDA DE MORATALAZ, 73      3   55.00            3       0
# 3          AVENIDA DE MORATALAZ, 85   BAJO   54.60            3       0
# 4  AVENIDA DOCTOR GARCIA TAPIA, 102     BJ   43.50            2       0
#
#    Precio  eur_metro  eur_metro_round planta_cat                        Calle  \
# 0   850.0  10.000000             10.0         02         AVENIDA DE MORATALAZ
# 1   600.0  14.398848             14.4         04         AVENIDA DE MORATALAZ
# 2   620.0  11.272727             11.3         03         AVENIDA DE MORATALAZ
# 3   650.0  11.904762             11.9         BJ         AVENIDA DE MORATALAZ
# 4   600.0  13.793103             13.8         BJ  AVENIDA DOCTOR GARCIA TAPIA
#
#   numero
# 0    103
# 1     29
# 2     73
# 3     85
# 4    102

# %%
pd.set_option('display.max_columns', None)

# %%
cat_data.head()
# Out:
#   cod_del_MEH cod_muni_DGC clase_BI     parcela_cat num_cargo num_fijo_BI  \
# 0          28          900       UR  1965204VK4716F      0001    00257650
# 1          28          900       UR  9437605VK3793G      0001    81140056
# 2          28          900       UR  0148301VK4704G      0001    00001774
# 3          28          900       UR  0148301VK4704G      0002    00001775
# 4          28          900       UR  0148301VK4704G      0003    00001776
#
#           BI_ayunt num_finca_registral cprov provincia cmun_DGC cmun_ine  \
# 0  000000000255496               00000    28    MADRID      900      079
# 1  000000000063083               00000    28    MADRID      900      079
# 2  000000000079248       2810802002614    28    MADRID      900      079
# 3  000000000079249       2810802002616    28    MADRID      900      079
# 4  000000000079250       2810802002618    28    MADRID      900      079
#
#   municipio entidad_menor cvia_DGC tipo_via      nombre_via num_pol1  bis  \
# 0    MADRID           NaN    01365       CL  CLAUDIO COELLO     0139  NaN
# 1    MADRID           NaN    05269       CL         ROSARIO     0000  NaN
# 2    MADRID           NaN    05859       CL           SILVA     0002  NaN
# 3    MADRID           NaN    05859       CL           SILVA     0002  NaN
# 4    MADRID           NaN    05859       CL           SILVA     0002  NaN
#
#   num_pol2 bis2     Km bloque escalera planta puerta dir_resto cod_postal  \
# 0     0000  NaN  00000    NaN        T     OD     OS      0000      28006
# 1     0000  NaN  00000    NaN        S     UE     LO       NaN      28005
# 2     0000  NaN  00000    NaN      NaN     -4     01       NaN      28013
# 3     0000  NaN  00000    NaN      NaN     -4     02       NaN      28013
# 4     0000  NaN  00000    NaN      NaN     -4     03       NaN      28013
#
#   distrito antiguedad_BI clave_grupo_BI       m2_BI m2_solares_sin_div_hor  \
# 0       04          1975              G  0000021526             0000002321
# 1       01             0              M  0000000000             0000001150
# 2       01          1984              A  0000000023             0000000631
# 3       01          1984              A  0000000023             0000000631
# 4       01          1984              A  0000000023             0000000631
#
#   coef_finca garage num_orden_BI aniot14 anio_mejor     x_coor      y_coor  \
# 0  100000000      0          NaN       0       1975  441827.64  4476294.63
# 1  100000000      0          NaN       0          0   439356.7  4473478.15
# 2  000070000      0          NaN       0       1984  439945.24  4474677.58
# 3  000070000      0          NaN       0       1984  439945.24  4474677.58
# 4  000070000      0          NaN       0       1984  439945.24  4474677.58
#
#   huso_geo
# 0    25830
# 1    25830
# 2    25830
# 3    25830
# 4    25830

# %%
rawdata['numero']=rawdata['numero'].str.strip()
rawdata['Calle']=rawdata['Calle'].str.strip()

# %%
rawdata[rawdata['numero'].str.isdigit() == False]
# Out:
#                                          Direccion Planta   metros  \
# 52       CALLE CORREGIDOR DIEGO CABEZA DE VACA, 9B      4   61.190
# 172              AVENIDA MONASTERIO DE SILOS, 80-A     1º   57.180
# 222              CALLE CASTILLO DE CANDANCHU, 48 A      6   85.000
# 541                   CALLE AMOS DE ESCALANTE, 7-9      1   54.000
# 603                                CALLE ELFO, 78A      6   53.150
# 611          CALLE EMILIO GASTESI FERNANDEZ, 40-46     4º   80.290
# 683               CALLE JOSE FELIU Y CODINA, 5 BIS      2   67.000
# 763                     CALLE RAFAEL BERGAMIN, 20B      3   52.920
# 903                               CALLE CALIZA, 8B      2   81.600
# 934             CALLE LADERA DE LOS ALMENDROS, 12A      2   73.349
# 936            CALLE LADERA DE LOS ALMENDROS, 18-D     3º   53.900
# 5175               CALLE PEÑA DE LA ATALAYA     92-94
# 5386                           CALLE GALEON       18/
# 5394                       CALLE PLUS ULTRA        7C
#
# [65 rows x 11 columns]

# %%
# Sustituimos los nulos de número por ''

# %%
rawdata.loc[rawdata['numero'].isnull(), 'numero'] = ''

# Elimnar espacios del campo numero

rawdata['numero'] = rawdata['numero'].str.replace(' ', '')

# %%
# Analizamos el tipo de separador que hay en el campo 'numero'. (hay '-' y '/')

# %%
separadores = rawdata[rawdata['numero'].str.contains('\W+')]['numero'].str.extract('(\W+)').unique()
# Out:
# /home/manu/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   if __name__ == '__main__':

# %%
separadores
# Out:
# array(['-', '/'], dtype=object)

# %%
for separador in separadores:
    rawdata['numero'] = rawdata['numero'].str.replace(separador, '-')

# %%
rawdata[rawdata['numero'].str.contains('\W+')]
# Out:
#                                    Direccion Planta  metros habitaciones  \
# 172        AVENIDA MONASTERIO DE SILOS, 80-A     1º   57.18            2
# 541             CALLE AMOS DE ESCALANTE, 7-9      1   54.00            1
# 611    CALLE EMILIO GASTESI FERNANDEZ, 40-46     4º   80.29            3
# 936      CALLE LADERA DE LOS ALMENDROS, 18-D     3º   53.90            2
# 983              CALLE SAN CIRPIRIANO, 50-52      4   74.00            3
# 1009            CALLE AGUSTIN DE FOXA, 16-18      5   34.50            1
# 1194             PASEO DE LA HABANA, 148-150      4   63.00            2
# 1214           AVENIDA DE LAS SUERTES, 67- E      4   75.30            3
# 1219      AVENIDA DEL CERRO MILANO, 141 -143      1   46.00            1
# 1261          CALLE ALAMEDA DEL VALLE, 21-23      2   91.43            2
# 1262          CALLE ALAMEDA DEL VALLE, 21-23      4   51.61            1
# 1505                   CALLE AQUITANIA, 73-A      5   52.74            2
# 1748                      CALLE ALGETE, 2-10      5   39.93          NaN
# 2016       AVENIDA CARABANCHEL ALTO, 35 - 37      1   76.03            3
# 2351                 CALLE JACOBINIA, 32-BIS     BJ   65.10            2
# 2824                     CALLE AZUCENAS, 2-4      1   57.84            1
# 2841                 CALLE BERRUGUETE, 57-59      1   89.90            3
# 3029               CALLE JUAN SANCHEZ, 16-18      9   93.17            3
# 3034                 CALLE LAS MATAS, 13-BIS     BJ   30.00            1
# 3098  CALLE NUESTRA SEÑORA DEL CARMEN, 45-47      1   60.00            2
# 3099  CALLE NUESTRA SEÑORA DEL CARMEN, 45-47      1   65.43            2
# 3107                     CALLE ORENSE, 18/20      4   49.62            2
# 4056              CALLE ANA DE AUSTRIA, 31-A     2º  100.32            4
# 5156                   CALLE MONTSENY, 44-46      2   42.29            1
# 5175         CALLE PEÑA DE LA ATALAYA, 92-94     1º   67.19            2
# 5386                       CALLE GALEON, 18/      5   64.03            2
#
#       Garaje  Precio  eur_metro  eur_metro_round planta_cat  \
# 172        1  1000.0  17.488632             17.5         01
# 541        0   700.0  12.962963             13.0         01
# 611        0   750.0   9.341138              9.3         04
# 936        1   750.0  13.914657             13.9         03
# 983        0   750.0  10.135135             10.1         04
# 1009       0   750.0  21.739130             21.7         05
# 1194       0   900.0  14.285714             14.3         04
# 1214       1   850.0  11.288181             11.3         04
# 1219       1   590.0  12.826087             12.8         01
# 1261       0   850.0   9.296730              9.3         02
# 1262       1   600.0  11.625654             11.6         04
# 1505       1   600.0  11.376564             11.4         05
# 1748       0   725.0  18.156774             18.2         05
# 2016       1   795.0  10.456399             10.5         01
# 2351       0   550.0   8.448541              8.4         BJ
# 2824       0   650.0  11.237898             11.2         01
# 2841       0   950.0  10.567297             10.6         01
# 3029       1   950.0  10.196415             10.2         09
# 3034       0   550.0  18.333333             18.3         BJ
# 3098       1   700.0  11.666667             11.7         01
# 3099       0   650.0   9.934281              9.9         01
# 3107       0   750.0  15.114873             15.1         04
# 4056       1  1050.0  10.466507             10.5         02
# 5156       0   625.0  14.778908             14.8         02
# 5175       1   700.0  10.418217             10.4         01
# 5386       0   850.0  13.275027             13.3         05
#
#                                 Calle   numero
# 172       AVENIDA MONASTERIO DE SILOS     80-A
# 541           CALLE AMOS DE ESCALANTE      7-9
# 611    CALLE EMILIO GASTESI FERNANDEZ    40-46
# 936     CALLE LADERA DE LOS ALMENDROS     18-D
# 983              CALLE SAN CIRPIRIANO    50-52
# 1009            CALLE AGUSTIN DE FOXA    16-18
# 1194               PASEO DE LA HABANA  148-150
# 1214           AVENIDA DE LAS SUERTES     67-E
# 1219         AVENIDA DEL CERRO MILANO  141-143
# 1261          CALLE ALAMEDA DEL VALLE    21-23
# 1262          CALLE ALAMEDA DEL VALLE    21-23
# 1505                  CALLE AQUITANIA     73-A
# 1748                     CALLE ALGETE     2-10
# 2016         AVENIDA CARABANCHEL ALTO    35-37
# 2351                  CALLE JACOBINIA   32-BIS
# 2824                   CALLE AZUCENAS      2-4
# 2841                 CALLE BERRUGUETE    57-59
# 3029               CALLE JUAN SANCHEZ    16-18
# 3034                  CALLE LAS MATAS   13-BIS
# 3098  CALLE NUESTRA SEÑORA DEL CARMEN    45-47
# 3099  CALLE NUESTRA SEÑORA DEL CARMEN    45-47
# 3107                     CALLE ORENSE    18-20
# 4056             CALLE ANA DE AUSTRIA     31-A
# 5156                   CALLE MONTSENY    44-46
# 5175         CALLE PEÑA DE LA ATALAYA    92-94
# 5386                     CALLE GALEON      18-

# %%
# Separamos en el número si hay parte de Bis/Duplicado

# %%
numeros_tratar = rawdata[rawdata['numero'].str.isdigit() == False]

# %%
# Tratamos de forma diferente si hay un - o no

# %%
numeros_guion = numeros_tratar[numeros_tratar['numero'].str.find('-') != -1]

# %%
numeros_guion.head()
# Out:
#                                  Direccion Planta  metros habitaciones  \
# 172      AVENIDA MONASTERIO DE SILOS, 80-A     1º   57.18            2
# 541           CALLE AMOS DE ESCALANTE, 7-9      1   54.00            1
# 611  CALLE EMILIO GASTESI FERNANDEZ, 40-46     4º   80.29            3
# 936    CALLE LADERA DE LOS ALMENDROS, 18-D     3º   53.90            2
# 983            CALLE SAN CIRPIRIANO, 50-52      4   74.00            3
#
#      Garaje  Precio  eur_metro  eur_metro_round planta_cat  \
# 172       1  1000.0  17.488632             17.5         01
# 541       0   700.0  12.962963             13.0         01
# 611       0   750.0   9.341138              9.3         04
# 936       1   750.0  13.914657             13.9         03
# 983       0   750.0  10.135135             10.1         04
#
#                               Calle numero
# 172     AVENIDA MONASTERIO DE SILOS   80-A
# 541         CALLE AMOS DE ESCALANTE    7-9
# 611  CALLE EMILIO GASTESI FERNANDEZ  40-46
# 936   CALLE LADERA DE LOS ALMENDROS   18-D
# 983            CALLE SAN CIRPIRIANO  50-52

# %%
## Separamos por el guion y en el segundo campo sustituimos BIS por B

# %%
num_bis_guion = numeros_guion['numero'].str.split('-', expand = True)

# %%
num_bis_guion.rename(columns = {0:'num_pol', 1:'letra'}, inplace=True)

# %%
num_bis_guion
# Out:
#      num_pol letra
# 172       80     A
# 541        7     9
# 611       40    46
# 936       18     D
# 983       50    52
# 1009      16    18
# 1194     148   150
# 1214      67     E
# 1219     141   143
# 1261      21    23
# 1262      21    23
# 1505      73     A
# 1748       2    10
# 2016      35    37
# 2351      32   BIS
# 2824       2     4
# 2841      57    59
# 3029      16    18
# 3034      13   BIS
# 3098      45    47
# 3099      45    47
# 3107      18    20
# 4056      31     A
# 5156      44    46
# 5175      92    94
# 5386      18

# %%
# las letras no pueden ser números, vaciamos las que lo sean

# %%
num_bis_guion['letra'] = num_bis_guion['letra'].apply(lambda x: '' if x.isdigit() else x)

# %%
num_bis_guion['letra'] = num_bis_guion['letra'].replace('BIS', 'B')

# %%
# Tratamos los que no tienen -

# %%
numeros_no_guion = numeros_tratar[numeros_tratar['numero'].str.find('-') == -1]

# %%
numeros_no_guion = numeros_no_guion.drop(numeros_no_guion.columns[:-1], axis=1)

# %%
numeros_no_guion['numero'] = numeros_no_guion['numero'].str.replace('BIS', 'B')

# %%
numeros_no_guion.head()
# Out:
#     numero
# 52      9B
# 222    48A
# 603    78A
# 683     5B
# 763    20B

# %%
numeros_no_guion['num_pol'] = numeros_no_guion['numero'].str.extract('(\d+)', expand = True)

# %%
numeros_no_guion['letra'] = numeros_no_guion['numero'].str.extract('(\D+)', expand = True)

# %%
numeros_no_guion.drop('numero', axis=1, inplace=True)

# %%
## Unimos los resultados y añadimos a la tabla global

# %%
rawdata = pd.concat([rawdata, pd.concat([num_bis_guion, numeros_no_guion])], axis=1)

# %%
rawdata.loc[rawdata['num_pol'].isnull(), 'num_pol'] = rawdata['numero']

# %%
rawdata.loc[rawdata['letra'].isnull(), 'letra'] = ''

# %%
rawdata.head(10)
# Out:
#                           Direccion Planta  metros habitaciones  Garaje  \
# 0         AVENIDA DE MORATALAZ, 103      2   85.00            3       0
# 1          AVENIDA DE MORATALAZ, 29      4   41.67            2       0
# 2          AVENIDA DE MORATALAZ, 73      3   55.00            3       0
# 3          AVENIDA DE MORATALAZ, 85   BAJO   54.60            3       0
# 4  AVENIDA DOCTOR GARCIA TAPIA, 102     BJ   43.50            2       0
# 5  AVENIDA DOCTOR GARCIA TAPIA, 124     2º   81.80            3       0
# 6  AVENIDA DOCTOR GARCIA TAPIA, 161      2   77.86            2       1
# 7            AVENIDA MORATALAZ, 108      4   48.00            3       0
# 8            AVENIDA MORATALAZ, 126    BJO   51.50            2       0
# 9            AVENIDA MORATALAZ, 136     6º   51.90            3       0
#
#    Precio  eur_metro  eur_metro_round planta_cat                        Calle  \
# 0   850.0  10.000000             10.0         02         AVENIDA DE MORATALAZ
# 1   600.0  14.398848             14.4         04         AVENIDA DE MORATALAZ
# 2   620.0  11.272727             11.3         03         AVENIDA DE MORATALAZ
# 3   650.0  11.904762             11.9         BJ         AVENIDA DE MORATALAZ
# 4   600.0  13.793103             13.8         BJ  AVENIDA DOCTOR GARCIA TAPIA
# 5   600.0   7.334963              7.3         02  AVENIDA DOCTOR GARCIA TAPIA
# 6   800.0  10.274852             10.3         02  AVENIDA DOCTOR GARCIA TAPIA
# 7   600.0  12.500000             12.5         04            AVENIDA MORATALAZ
# 8   650.0  12.621359             12.6         BJ            AVENIDA MORATALAZ
# 9   700.0  13.487476             13.5         06            AVENIDA MORATALAZ
#
#   numero num_pol letra
# 0    103     103
# 1     29      29
# 2     73      73
# 3     85      85
# 4    102     102
# 5    124     124
# 6    161     161
# 7    108     108
# 8    126     126
# 9    136     136

# %%
rawdata.loc[rawdata['letra']<>'',  'letra']
# Out:
# 52         B
# 172        A
# 222        A
# 603        A
# 683        B
# 763        B
# 903        B
# 934        A
# 936        D
# 937        A
# 941        A
# 972        A
# 1112       B
# 1213       D
# 1214       E
# 1230       D
# 1347       A
# 1391       E
# 1505       A
# 1509       A
# 1759       B
# 1855       E
# 1937       A
# 1982       C
# 2081       B
# 2192       B
# 2244       F
# 2351       B
# 2416       B
# 2430       F
# 2869       D
# 2901    DPLI
# 2968       B
# 3034       B
# 3421       G
# 3562       B
# 3889       B
# 4056       A
# 4490       B
# 4681       A
# 4696       G
# 4772      BI
# 5089       B
# 5158       B
# 5394       C
# Name: letra, dtype: object

# %%
## En las letras con más de un caracter dejamos sólo el primero
rawdata.loc[rawdata['letra'] <> '', 'letra'] = rawdata['letra'].str[0]

# %%
## Los números de policia de catastro tienen 4 caracteres
rawdata['num_pol'] = rawdata['num_pol'].str.rjust(width = 4, fillchar='0')

# %%
rawdata['planta_cat'].value_counts().sum()
# Out:
# 5649

# %%
rawdata.shape
# Out:
# (5654, 13)

# %%
rawdata['planta_cat'].value_counts()
# Out:
# 01    1175
# 02    1138
# 03    1052
# 04     734
# BJ     543
# 05     346
# 06     230
# 07     135
# 08      89
# 09      53
# 10      36
# 11      27
# SS      26
# AT      23
# 12      12
# 13       9
# EN       7
# 14       5
# EP       2
# 00       2
# 0D       1
# 0B       1
# 17       1
# SM       1
# LO       1
# Name: planta_cat, dtype: int64

# %%
rawdata['letra'].value_counts()
# Out:
#      5609
# B      18
# A      13
# D       5
# E       3
# G       2
# F       2
# C       2
# Name: letra, dtype: int64

# %%
rawdata.to_csv(os.path.join(out_dir, 'fincas_ivima.csv'), index = False, sep='^')
